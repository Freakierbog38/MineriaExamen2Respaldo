# %%
import pandas as pd
import numpy as np

df = pd.read_csv('weatherAUS.csv')
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# 1         WNW           44.0        NNW  ...        25.0       1010.6
# 2         WSW           46.0          W  ...        30.0       1007.6
# 3          NE           24.0         SE  ...        16.0       1017.6
# 4           W           41.0        ENE  ...        33.0       1010.8
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# 0       1007.1       8.0       NaN     16.9     21.8         No      0.0
# 1       1007.8       NaN       NaN     17.2     24.3         No      0.0
# 2       1008.7       NaN       2.0     21.0     23.2         No      0.0
# 3       1012.8       NaN       NaN     18.1     26.5         No      1.0
# 4       1006.0       7.0       8.0     17.8     29.7         No      0.2
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142193 entries, 0 to 142192
# Data columns (total 24 columns):
# Date             142193 non-null object
# Location         142193 non-null object
# MinTemp          141556 non-null float64
# MaxTemp          141871 non-null float64
# Rainfall         140787 non-null float64
# Evaporation      81350 non-null float64
# Sunshine         74377 non-null float64
# WindGustDir      132863 non-null object
# WindGustSpeed    132923 non-null float64
# WindDir9am       132180 non-null object
# WindDir3pm       138415 non-null object
# WindSpeed9am     140845 non-null float64
# WindSpeed3pm     139563 non-null float64
# Humidity9am      140419 non-null float64
# Humidity3pm      138583 non-null float64
# Pressure9am      128179 non-null float64
# Pressure3pm      128212 non-null float64
# Cloud9am         88536 non-null float64
# Cloud3pm         85099 non-null float64
# Temp9am          141289 non-null float64
# Temp3pm          139467 non-null float64
# RainToday        140787 non-null object
# RISK_MM          142193 non-null float64
# RainTomorrow     142193 non-null object
# dtypes: float64(17), object(7)
# memory usage: 26.0+ MB

# %%
to_drop = [
    'Date',
    'Location',
    'WindGustDir',
    'WindDir9am',
    'WindDir3pm',
    'RainToday',
    'RISK_MM'
]

df.drop(to_drop, inplace=True, axis=1)

# %%
df.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0     13.4     22.9       0.6          NaN       NaN           44.0
# 1      7.4     25.1       0.0          NaN       NaN           44.0
# 2     12.9     25.7       0.0          NaN       NaN           46.0
# 3      9.2     28.0       0.0          NaN       NaN           24.0
# 4     17.5     32.3       1.0          NaN       NaN           41.0
#
#    WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 0          20.0          24.0         71.0         22.0       1007.7
# 1           4.0          22.0         44.0         25.0       1010.6
# 2          19.0          26.0         38.0         30.0       1007.6
# 3          11.0           9.0         45.0         16.0       1017.6
# 4           7.0          20.0         82.0         33.0       1010.8
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm RainTomorrow
# 0       1007.1       8.0       NaN     16.9     21.8           No
# 1       1007.8       NaN       NaN     17.2     24.3           No
# 2       1008.7       NaN       2.0     21.0     23.2           No
# 3       1012.8       NaN       NaN     18.1     26.5           No
# 4       1006.0       7.0       8.0     17.8     29.7           No

# %%
rs = np.random.RandomState(0)
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row0_col1 {
#             background-color:  #e9785d;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row0_col2 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row0_col3 {
#             background-color:  #f6bea4;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row0_col4 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row0_col5 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row0_col6 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row0_col7 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row0_col8 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row0_col9 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row0_col10 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row0_col11 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row0_col12 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row0_col13 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row0_col14 {
#             background-color:  #cc403a;
#             color:  #f1f1f1;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row0_col15 {
#             background-color:  #eb7d62;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row1_col0 {
#             background-color:  #ea7b60;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row1_col2 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row1_col3 {
#             background-color:  #f6a283;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row1_col4 {
#             background-color:  #f7b093;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row1_col5 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row1_col6 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row1_col7 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row1_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row1_col9 {
#             background-color:  #506bda;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row1_col10 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row1_col11 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row1_col12 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row1_col13 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row1_col14 {
#             background-color:  #cf453c;
#             color:  #f1f1f1;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row1_col15 {
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row2_col0 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row2_col1 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row2_col3 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row2_col4 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row2_col5 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row2_col6 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row2_col7 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row2_col8 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row2_col9 {
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row2_col10 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row2_col11 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row2_col12 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row2_col13 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row2_col14 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row2_col15 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row3_col0 {
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row3_col1 {
#             background-color:  #f6a283;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row3_col2 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row3_col4 {
#             background-color:  #f5c4ac;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row3_col5 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row3_col6 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row3_col7 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row3_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row3_col9 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row3_col10 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_a411f21c_5ccb_11e9_a8b8_3c9509f5d955row3_col11 {
#             background-color:  #5f7fe8;

# %%
cleaned = df.fillna(0)
cleaned = cleaned.replace({'RainTomorrow' : {'No':-1, 'Yes':1}})

# %%
cleaned
# Out:
#         MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0          13.4     22.9       0.6          0.0       0.0           44.0
# 1           7.4     25.1       0.0          0.0       0.0           44.0
# 2          12.9     25.7       0.0          0.0       0.0           46.0
# 3           9.2     28.0       0.0          0.0       0.0           24.0
# 4          17.5     32.3       1.0          0.0       0.0           41.0
# 5          14.6     29.7       0.2          0.0       0.0           56.0
# 6          14.3     25.0       0.0          0.0       0.0           50.0
# 7           7.7     26.7       0.0          0.0       0.0           35.0
# 8           9.7     31.9       0.0          0.0       0.0           80.0
# 9          13.1     30.1       1.4          0.0       0.0           28.0
# 10         13.4     30.4       0.0          0.0       0.0           30.0
# 11         15.9     21.7       2.2          0.0       0.0           31.0
# 12         15.9     18.6      15.6          0.0       0.0           61.0
# 13         12.6     21.0       3.6          0.0       0.0           44.0
# 14          9.8     27.7       0.0          0.0       0.0           50.0
# 15         14.1     20.9       0.0          0.0       0.0           22.0
# 16         13.5     22.9      16.8          0.0       0.0           63.0
# 17         11.2     22.5      10.6          0.0       0.0           43.0
# 18          9.8     25.6       0.0          0.0       0.0           26.0
# 19         11.5     29.3       0.0          0.0       0.0           24.0
# 20         17.1     33.0       0.0          0.0       0.0           43.0
# 21         20.5     31.8       0.0          0.0       0.0           41.0
# 22         15.3     30.9       0.0          0.0       0.0           33.0
# 23         12.6     32.4       0.0          0.0       0.0           43.0
# 24         16.2     33.9       0.0          0.0       0.0           35.0
# 25         16.9     33.0       0.0          0.0       0.0           57.0
# 26         20.1     32.7       0.0          0.0       0.0           48.0
# 27         19.7     27.2       0.0          0.0       0.0           46.0
# 28         12.5     24.2       1.2          0.0       0.0           50.0
# 29         12.0     24.4       0.8          0.0       0.0           39.0
# ...         ...      ...       ...          ...       ...            ...
# 142163     14.3     27.6       0.4          0.0       0.0           39.0
# 142164      9.3     28.0       0.0          0.0       0.0           28.0
# 142165      8.0     24.6       0.0          0.0       0.0           33.0
# 142166     12.7     22.2       0.0          0.0       0.0           37.0
# 142167      9.4     22.7       0.0          0.0       0.0           35.0
# 142168      5.4     20.5       0.0          0.0       0.0           46.0
# 142169      5.6     19.4       0.0          0.0       0.0           43.0
# 142170      1.5     19.2       0.0          0.0       0.0           37.0
# 142171      3.8     19.8       0.0          0.0       0.0           39.0
# 142172      4.5     18.8       0.0          0.0       0.0           31.0
# 142173      4.9     20.7       0.0          0.0       0.0           37.0
# 142174      1.2     20.8       0.0          0.0       0.0           43.0
# 142175      0.5     21.7       0.0          0.0       0.0           43.0
# 142176      4.0     20.0       0.0          0.0       0.0           39.0
# 142177      3.4     19.8       0.0          0.0       0.0           43.0
# 142178      3.2     18.6       0.0          0.0       0.0           46.0
# 142179      2.4     19.1       0.0          0.0       0.0           33.0
# 142180      5.1     19.7       0.0          0.0       0.0           46.0
# 142181      2.5     21.2       0.0          0.0       0.0           35.0
# 142182      2.3     21.4       0.0          0.0       0.0           22.0
# 142183      2.6     22.5       0.0          0.0       0.0           19.0
# 142184      5.2     24.3       0.0          0.0       0.0           24.0
# 142185      6.4     23.4       0.0          0.0       0.0           31.0
# 142186      8.0     20.7       0.0          0.0       0.0           41.0
# 142187      7.4     20.6       0.0          0.0       0.0           35.0
# 142188      3.5     21.8       0.0          0.0       0.0           31.0
# 142189      2.8     23.4       0.0          0.0       0.0           31.0
# 142190      3.6     25.3       0.0          0.0       0.0           22.0
# 142191      5.4     26.9       0.0          0.0       0.0           37.0
# 142192      7.8     27.0       0.0          0.0       0.0           28.0
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 0               20.0          24.0         71.0         22.0       1007.7
# 1                4.0          22.0         44.0         25.0       1010.6
# 2               19.0          26.0         38.0         30.0       1007.6
# 3               11.0           9.0         45.0         16.0       1017.6
# 4                7.0          20.0         82.0         33.0       1010.8
# 5               19.0          24.0         55.0         23.0       1009.2
# 6               20.0          24.0         49.0         19.0       1009.6
# 7                6.0          17.0         48.0         19.0       1013.4
# 8                7.0          28.0         42.0          9.0       1008.9
# 9               15.0          11.0         58.0         27.0       1007.0
# 10              17.0           6.0         48.0         22.0       1011.8
# 11              15.0          13.0         89.0         91.0       1010.5
# 12              28.0          28.0         76.0         93.0        994.3
# 13              24.0          20.0         65.0         43.0       1001.2
# 14               0.0          22.0         50.0         28.0       1013.4
# 15              11.0           9.0         69.0         82.0       1012.2
# 16               6.0          20.0         80.0         65.0       1005.8
# 17              24.0          17.0         47.0         32.0       1009.4
# 18              17.0           6.0         45.0         26.0       1019.2
# 19               9.0           9.0         56.0         28.0       1019.3
# 20              17.0          22.0         38.0         28.0       1013.6
# 21              19.0          20.0         54.0         24.0       1007.8
# 22               6.0          13.0         55.0         23.0       1011.0
# 23               4.0          19.0         49.0         17.0       1012.9
# 24               9.0          13.0         45.0         19.0       1010.9
# 25               0.0          26.0         41.0         28.0       1006.8
# 26              13.0          30.0         56.0         15.0       1005.2
# 27              19.0          30.0         49.0         22.0       1004.8
# 28              11.0          22.0         78.0         70.0       1005.6
# 29              17.0          17.0         48.0         28.0       1006.1
# ...              ...           ...          ...          ...          ...
# 142163           0.0          20.0         68.0         27.0       1020.5
# 142164           6.0          11.0         36.0         16.0       1019.9
# 142165          11.0          13.0         46.0         25.0       1021.7
# 142166          19.0          13.0         59.0         34.0       1024.3
# 142167          13.0          17.0         62.0         32.0       1026.6
# 142168          20.0          28.0         56.0         32.0       1029.2
# 142169          22.0          24.0         61.0         22.0       1029.6
# 142170          17.0          22.0         45.0         18.0       1030.7
# 142171          19.0          17.0         42.0         22.0       1028.7
# 142172          13.0          15.0         42.0         26.0       1026.9
# 142173          17.0          24.0         38.0         11.0       1027.1
# 142174          13.0          28.0         29.0          6.0       1029.8
# 142175          13.0          20.0         27.0         19.0       1029.0
# 142176          13.0          26.0         58.0         26.0       1030.2
# 142177          19.0          24.0         54.0         23.0       1031.8
# 142178          15.0          20.0         56.0         29.0       1031.0
# 142179          17.0          17.0         59.0         24.0       1030.0
# 142180          13.0          17.0         56.0         29.0       1028.5
# 142181          17.0          19.0         57.0         32.0       1027.2
# 142182          11.0           7.0         60.0         28.0       1026.9
# 142183           9.0           7.0         59.0         24.0       1025.0
# 142184          11.0          11.0         53.0         24.0       1023.8
# 142185          15.0          17.0         53.0         25.0       1025.8
# 142186          19.0          26.0         56.0         32.0       1028.1
# 142187          15.0          17.0         63.0         33.0       1027.2
# 142188          15.0          13.0         59.0         27.0       1024.7
# 142189          13.0          11.0         51.0         24.0       1024.6
# 142190          13.0           9.0         56.0         21.0       1023.5
# 142191           9.0           9.0         53.0         24.0       1021.0
# 142192          13.0           7.0         51.0         24.0       1019.4
#
#         Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainTomorrow
# 0            1007.1       8.0       0.0     16.9     21.8            -1
# 1            1007.8       0.0       0.0     17.2     24.3            -1
# 2            1008.7       0.0       2.0     21.0     23.2            -1
# 3            1012.8       0.0       0.0     18.1     26.5            -1
# 4            1006.0       7.0       8.0     17.8     29.7            -1
# 5            1005.4       0.0       0.0     20.6     28.9            -1
# 6            1008.2       1.0       0.0     18.1     24.6            -1
# 7            1010.1       0.0       0.0     16.3     25.5            -1
# 8            1003.6       0.0       0.0     18.3     30.2             1
# 9            1005.7       0.0       0.0     20.1     28.2            -1
# 10           1008.7       0.0       0.0     20.4     28.8             1
# 11           1004.2       8.0       8.0     15.9     17.0             1
# 12            993.0       8.0       8.0     17.4     15.8             1
# 13           1001.8       0.0       7.0     15.8     19.8            -1
# 14           1010.3       0.0       0.0     17.3     26.2            -1
# 15           1010.4       8.0       1.0     17.2     18.1             1
# 16           1002.2       8.0       1.0     18.0     21.5             1
# 17           1009.7       0.0       2.0     15.5     21.0            -1
# 18           1017.1       0.0       0.0     15.8     23.2            -1
# 19           1014.8       0.0       0.0     19.1     27.3            -1
# 20           1008.1       0.0       1.0     24.5     31.6            -1
# 21           1005.7       0.0       0.0     23.8     30.8            -1
# 22           1008.2       5.0       0.0     20.9     29.0            -1
# 23           1010.1       0.0       0.0     21.5     31.2            -1
# 24           1007.6       0.0       1.0     23.2     33.0            -1
# 25           1003.6       0.0       1.0     26.6     31.2            -1
# 26           1001.7       0.0       0.0     24.6     32.1            -1
# 27           1004.2       0.0       0.0     21.6     26.1             1
# 28           1003.4       8.0       8.0     12.5     18.2            -1
# 29           1005.1       1.0       0.0     16.9     22.7            -1
# ...             ...       ...       ...      ...      ...           ...
# 142163       1016.1       4.0       7.0     16.1     27.2            -1
# 142164       1016.9       0.0       0.0     16.6     27.3            -1
# 142165       1018.8       4.0       0.0     13.8     23.5            -1
# 142166       1021.7       8.0       8.0     13.9     21.0            -1
# 142167       1023.6       8.0       4.0     11.8     22.3            -1
# 142168       1025.3       0.0       0.0     11.1     20.2            -1
# 142169       1027.1       0.0       0.0      9.7     18.3            -1
# 142170       1026.7       0.0       0.0      6.8     17.6            -1
# 142171       1024.1       0.0       0.0      8.6     18.9            -1
# 142172       1022.4       0.0       0.0      9.5     18.6            -1
# 142173       1023.9       0.0       0.0     10.3     19.8            -1
# 142174       1025.9       0.0       0.0      7.9     19.9            -1
# 142175       1025.0       0.0       0.0      9.5     20.5            -1
# 142176       1026.7       0.0       0.0      9.1     19.0            -1
# 142177       1027.7       0.0       0.0      8.7     18.9            -1
# 142178       1027.2       0.0       0.0      8.2     17.4            -1
# 142179       1026.2       0.0       0.0      8.0     18.8            -1
# 142180       1025.8       0.0       0.0      8.5     19.2            -1
# 142181       1023.0       0.0       0.0     10.3     20.3            -1
# 142182       1022.8       0.0       0.0      8.9     20.3            -1
# 142183       1021.4       0.0       0.0      8.8     22.1            -1
# 142184       1020.0       0.0       0.0     12.3     23.3            -1
# 142185       1023.0       0.0       0.0     11.2     23.1            -1
# 142186       1024.3       0.0       7.0     11.6     20.0            -1
# 142187       1023.3       0.0       0.0     11.0     20.3            -1
# 142188       1021.2       0.0       0.0      9.4     20.9            -1
# 142189       1020.3       0.0       0.0     10.1     22.4            -1
# 142190       1019.1       0.0       0.0     10.9     24.5            -1
# 142191       1016.8       0.0       0.0     12.5     26.1            -1
# 142192       1016.5       3.0       2.0     15.1     26.0            -1
#
# [142193 rows x 17 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X, y = cleaned.iloc[:,:-1].values, cleaned.iloc[:,-1].values

train, test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1, stratify=y)

# standardize the features
sc = StandardScaler()
sc.fit(train)
X_train_std = sc.transform(train)
X_test_std = sc.transform(test)

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators=5, random_state=0)

# %%
from sklearn.model_selection import cross_val_score
all_accuracies = cross_val_score(estimator=classifier, X=X_train_std, y=y_train, cv=5)

# %%
print(all_accuracies.mean())
# Out:
# 0.8262420065706925

# %%
from plot_regions import plot_decision_regions
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

pca = PCA(n_components=2)
lr = LogisticRegression()

X_train_pca = pca.fit_transform(X_train_std)
X_test_pca = pca.transform(X_test_std)
lr.fit(X_train_pca, y_train)
plot_decision_regions(X_train_pca, y_train, classifier=lr)

plt.xlabel('PC 1')
plt.ylabel('PC 2')
plt.legend(loc='lower left')
plt.show()
# Out:
# /home/miguelruiz/.local/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
# test the transformed test dataset
plot_decision_regions(X_test_pca, y_test, classifier=lr)
plt.xlabel('PC 1')
plt.ylabel('PC 2')
plt.legend(loc='lower left')
plt.show()

# %%
pca = PCA(n_components=None)
X_train_pca = pca.fit_transform(X_train_std)
pca.explained_variance_ratio_
# Out:
# array([0.27410061, 0.17036145, 0.11592107, 0.10836161, 0.07892464,
#        0.05353507, 0.04629362, 0.03345165, 0.02888824, 0.02446317,
#        0.02360632, 0.01890765, 0.01366139, 0.00517   , 0.00337454,
#        0.00097896])

# %%
from sklearn import svm
from sklearn.model_selection import GridSearchCV

grid_params = {
    'n_estimators': [1, 3, 5, 8, 10],
    'criterion': ['gini', 'entropy'],
    'bootstrap': [True, False]
}

gd_sr = GridSearchCV(estimator=classifier,
                    param_grid=grid_params,
                    scoring='accuracy',
                    cv=5,
                    n_jobs=1)

# %%
gd_sr.fit(X_train_std, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=5, n_jobs=None,
#             oob_score=False, random_state=0, verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=1,
#        param_grid={'n_estimators': [1, 3, 5, 8, 10], 'criterion': ['gini', 'entropy'], 'bootstrap': [True, False]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='accuracy', verbose=0)

# %%
best_parameters= gd_sr.best_params_
print(best_parameters)
# Out:
# {'bootstrap': False, 'criterion': 'entropy', 'n_estimators': 10}

# %%
best_result = gd_sr.best_score_
print(best_result)
# Out:
# 0.8430401366353544

# %%
import matplotlib.pyplot as plt

plt.hist(X_train_std)
# Out:
# ([array([79041., 20494.,     0.,     0.,     0.,     0.,     0.,     0.,
#              0.,     0.]),
#   array([79246., 20289.,     0.,     0.,     0.,     0.,     0.,     0.,
#              0.,     0.]),
#   array([9.2842e+04, 6.1230e+03, 4.2900e+02, 9.9000e+01, 2.2000e+01,
#          1.2000e+01, 6.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00]),
#   array([8.2065e+04, 1.7276e+04, 1.5200e+02, 3.7000e+01, 4.0000e+00,
#          1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00]),
#   array([71977., 27558.,     0.,     0.,     0.,     0.,     0.,     0.,
#              0.,     0.]),
#   array([8.2425e+04, 1.7107e+04, 3.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00]),
#   array([8.0916e+04, 1.8602e+04, 1.6000e+01, 1.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00]),
#   array([8.2648e+04, 1.6880e+04, 7.0000e+00, 0.0000e+00, 0.0000e+00,
#          0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00]),
#   array([78757., 20778.,     0.,     0.,     0.,     0.,     0.,     0.,
#              0.,     0.]),
#   array([80683., 18852.,     0.,     0.,     0.,     0.,     0.,     0.,
#              0.,     0.]),
#   array([99535.,     0.,     0.,     0.,     0.,     0.,     0.,     0.,
#              0.,     0.]),
#   array([99535.,     0.,     0.,     0.,     0.,     0.,     0.,     0.,
#              0.,     0.]),
#   array([70055., 29480.,     0.,     0.,     0.,     0.,     0.,     0.,
#              0.,     0.]),
#   array([72031., 27504.,     0.,     0.,     0.,     0.,     0.,     0.,
#              0.,     0.]),
#   array([79660., 19875.,     0.,     0.,     0.,     0.,     0.,     0.,
#              0.,     0.]),
#   array([80130., 19405.,     0.,     0.,     0.,     0.,     0.,     0.,
#              0.,     0.])],
#  array([-3.89643463,  0.87892233,  5.65427929, 10.42963626, 15.20499322,
#         19.98035018, 24.75570714, 29.53106411, 34.30642107, 39.08177803,
#         43.85713499]),
#  <a list of 16 Lists of Patches objects>)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5, p=2, metric='minkowski')
knn.fit(X_train_std, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')

# %%
X_combined_std = np.vstack((X_train_std, X_test_std))
y_combined = np.hstack((y_train, y_test))

# %%
plot_decision_regions(X_combined_std, y_combined, classifier=knn)
plt.xlabel('petal length [standardized]')
plt.ylabel('petal width [standardized]')
plt.legend(loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-5516f3684462> in <module>
# ----> 1 plot_decision_regions(X_combined_std, y_combined, classifier=knn)
#       2 plt.xlabel('petal length [standardized]')
#       3 plt.ylabel('petal width [standardized]')
#       4 plt.legend(loc='upper left')
#       5 plt.show()
#
# ~/Escritorio/python/examen-recuperacion-u2-Freakierbog38/plot_regions.py in plot_decision_regions(x, y, classifier, test_idx, resolution)
#      14     x2_min, x2_max = x[:, 1].min() - 1, x[:, 1].max() + 1
#      15     xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution), np.arange(x2_min, x2_max, resolution))
# ---> 16     z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
#      17     z = z.reshape(xx1.shape)
#      18
#
# ~/.local/lib/python3.6/site-packages/sklearn/neighbors/classification.py in predict(self, X)
#     147         X = check_array(X, accept_sparse='csr')
#     148
# --> 149         neigh_dist, neigh_ind = self.kneighbors(X)
#     150         classes_ = self.classes_
#     151         _y = self._y
#
# ~/.local/lib/python3.6/site-packages/sklearn/neighbors/base.py in kneighbors(self, X, n_neighbors, return_distance)
#     453                 delayed_query(
#     454                     self._tree, X[s], n_neighbors, return_distance)
# --> 455                 for s in gen_even_slices(X.shape[0], n_jobs)
#     456             )
#     457         else:
#
# ~/.local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     915             # remaining jobs.
#     916             self._iterating = False
# --> 917             if self.dispatch_one_batch(iterator):
#     918                 self._iterating = self._original_iterator is not None
#     919
#
# ~/.local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# ~/.local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# ~/.local/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# ~/.local/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# ~/.local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~/.local/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~/.local/lib/python3.6/site-packages/sklearn/neighbors/base.py in _tree_query_parallel_helper(tree, data, n_neighbors, return_distance)
#     290     under PyPy.
#     291     """
# --> 292     return tree.query(data, n_neighbors, return_distance)
#     293
#     294
#
# sklearn/neighbors/binary_tree.pxi in sklearn.neighbors.kd_tree.BinaryTree.query()
#
# ValueError: query data dimension must match training data dimension
